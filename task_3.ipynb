# %%
from utils_task3 import RedditSubGraphDataset
import torch_sparse 

dataset = RedditSubGraphDataset(path='Reddit', num_graphs=1000, task_type='a')
# Out:
# Computing METIS partitioning...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 4
#       1 from utils_task3 import RedditSubGraphDataset
#       2 import torch_sparse
# ----> 4 dataset = RedditSubGraphDataset(path='Reddit', num_graphs=1000, task_type='a')
#
# File c:\Users\giaco\Desktop\Code\RoboticaMedica\Esame\Graph-Neural-Network\utils_task3.py:16, in RedditSubGraphDataset.__init__(self, path, num_graphs, task_type)
#      12 self.task_type = task_type
#      14 full_graph = Reddit(root=self.path)[0]
# ---> 16 self.train_graphs, self.val_graphs, self.test_graphs = self.partition_graph(full_graph)
#
# File c:\Users\giaco\Desktop\Code\RoboticaMedica\Esame\Graph-Neural-Network\utils_task3.py:19, in RedditSubGraphDataset.partition_graph(self, full_graph)
#      18 def partition_graph(self, full_graph):
# ---> 19     cluster_data = ClusterData(
# ...
